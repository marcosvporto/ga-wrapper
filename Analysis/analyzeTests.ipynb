# %%
import pandas as pd
# Out:
# /home/marcos/.pyenv/versions/3.7.2/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv("../Reports/gaWrapperTests.csv")

# %%
df[df['accuracy'] == df['accuracy'].max()]
# Out:
#     accuracy  features target selection  crossover  population  generations  \
# 18   0.84408        30     an         r          1         200           20
#
#     mutprob  crossprob  elitism
# 18     0.05        0.9     True

# %%
df.sort_values(by=['accuracy','features'], ascending=[False,True])
# Out:
#     accuracy  features target selection  crossover  population  generations  \
# 18  0.844080        30     an         r          1         200           20
# 14  0.842907        34     an         r          1          10           40
# 10  0.837046        30     an         r          1          10           40
# 17  0.835873        22     an         r          1         200           20
# 6   0.834701        30     an         r          1          10           20
# 16  0.833529        30     an         r          1         200           20
# 7   0.831184        32     an         r          1          10           20
# 2   0.830012        23     an         r          1          10           20
# 5   0.830012        38     an         r          1          10           20
# 12  0.828839        26     an         r          1          10           40
# 4   0.821805        26     an         r          1          10           20
# ...

# %%
df.sort_values(by='features', ascending=True)
# Out:
#     accuracy  features target selection  crossover  population  generations  \
# 15  0.797186        22     an         r          1          10           40
# 17  0.835873        22     an         r          1         200           20
# 2   0.830012        23     an         r          1          10           20
# 4   0.821805        26     an         r          1          10           20
# 12  0.828839        26     an         r          1          10           40
# 9   0.808910        27     an         r          1          10           40
# 13  0.797186        29     an         r          1          10           40
# 16  0.833529        30     an         r          1         200           20
# 11  0.807737        30     an         r          1          10           40
# 10  0.837046        30     an         r          1          10           40
# 0   0.813599        30     an         r          1          10           20
# ...
